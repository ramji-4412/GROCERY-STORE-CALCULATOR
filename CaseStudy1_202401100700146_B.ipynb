# %% [markdown]
# <a href="https://colab.research.google.com/github/ramji-4412/GROCERY-STORE-CALCULATOR/blob/main/CaseStudy1_202401100700146_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GROCERY STORE CALCULATOR

print("ALL IN ONE GENERAL STORE")

print("LIST OF ITEMS AVAILABLE :- ")
print("01. Flour")
print("02. Rice")
print("03. Pulses")
print("04. Salt")
print("05. Spices")
print("06. Milk")
print("07. Bread")
print("08. Lentils")
print("09. Cheese")
print("10. Yogurt")
print("11. Oils")
print("12. Biscuits")
print("13. Snacks")
print("14. Beverages")
print("15. Household Items")
print("16. Cleaning Items")
print("17. Toiletries")
print("18. Stationery Items")
print("19. Healthy Fats")
print("20. Beauty Items")
n = int(input("How many items you want to buy : "))
sum=0
for i in range(n) :
  item = input("Enter the item name : ")
  if(item == "Flour"):
    price = 15
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Rice"):
    price = 20
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Pulses"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Salt"):
    price = 5
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Spices"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Milk"):
    price = 20
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Bread"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Lentils"):
    price = 15
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Cheese"):
    price = 30
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Yogurt"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Oils"):
    price = 40
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Biscuits"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Snacks"):
    price = 15
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Beverages"):
    price = 20
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Household Items"):
    price = 10
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Cleaning Items"):
    price = 15
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Toiletries"):
    price = 20
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Stationery Items"):
    price = 5
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Healthy Fats"):
    price = 30
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
  elif(item == "Beauty Items"):
    price = 40
    print("Price is : ",price)
    choice=input("Want to buy : ")
    if(choice == "yes" or choice == "YES" or  choice == "Yes"):
      quantity = int(input("Enter the quantity : "))
      total = price * quantity
      print("Total price is : ",total)
      sum+=total
print("Your total amount is : ",sum)
if(sum>=100 and sum<200):
  print("Discount is 5%")
  amount = sum-((sum*5)/100)
  print("After discount AMOUNT PAYABLE IS : ",amount)
  print("THANK YOU FOR SHOPPING WITH US")
elif(sum>=200 and sum<300):
  print("Discount is 20%")
  amount = sum-((sum*10)/100)
  print("After discount AMOUNT PAYABLE IS : ",amount)
  print("THANK YOU FOR SHOPPING WITH US")
elif(sum>=300):
  print("Discount is 30%")
  amount = sum-((sum*15)/100)
  print("After discount AMOUNT PAYABLE IS : ",amount)
  print("THANK YOU FOR SHOPPING WITH US")
# Out:
# ALL IN ONE GENERAL STORE
# LIST OF ITEMS AVAILABLE :-
# 01. Flour
# 02. Rice
# 03. Pulses
# 04. Salt
# 05. Spices
# 06. Milk
# 07. Bread
# 08. Lentils
# 09. Cheese
# 10. Yogurt
# 11. Oils
# 12. Biscuits
# 13. Snacks
# 14. Beverages
# 15. Household Items
# 16. Cleaning Items
# 17. Toiletries
# 18. Stationery Items
# 19. Healthy Fats
# 20. Beauty Items
# How many items you want to buy : 3
# Enter the item name : Lentils
# Price is :  15
# Want to buy : Yes
# Enter the quantity : 5
# Total price is :  75
# Enter the item name : Snacks
# Price is :  15
# Want to buy : No
# Enter the item name : Flour
# Price is :  15
# Want to buy : Yes
# Enter the quantity : 10
# Total price is :  150
# Your total amount is :  225
# Discount is 5%
# After discount AMOUNT PAYABLE IS :  213.75
# THANK YOU FOR SHOPPING WITH US
